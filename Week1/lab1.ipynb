# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from openai import OpenAI
from IPython.display import Markdown, display
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from scraper import fetch_website_contents
#       4 from openai import OpenAI
#       5 from IPython.display import Markdown, display
#
# ImportError: cannot import name 'fetch_website_contents' from 'scraper' (/Users/yashasuttangi/Developer/WorkHorse/LLM-Engineering/LLM-Engineering/ai-env/lib/python3.10/site-packages/scraper/__init__.py)
